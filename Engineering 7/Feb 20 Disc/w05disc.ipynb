# %% [markdown]
# ---
#
# <h3><center>E7 -  Introduction to Programming for Scientists and Engineers</center></h3>
#
# <h2><center>Discussion week 5<br></center></h2>
#
# <h1><center>VSCode<br></center></h1>
#
# ---

# %%
f"{100:x}",f"{100:d}"f"{100:o}",f"{100:b}"
# Out:
# ('64', '100144', '1100100')

# %%
f"{1:.2f}"
# Out:
# '1.00'

# %% [markdown]
# ### Install

# %% [markdown]
# + [VSCode download page](https://code.visualstudio.com/Download)
# + [Python download page](https://www.python.org/downloads/)

# %% [markdown]
# ### pip
#
# Populate your Python environment with:

# %% [markdown]
# ```python
# pip install numpy matplotlib scipy otter-grader jupyter ipykernel
# ```
#
# or
#
# ```python
# pip install -r requirements_e7.txt
# ```

# %% [markdown]
# ### Debgugging example
#
# The function `find_max` is supposed to find the largest of the values in `numbers`.

# %%
def find_max(numbers):
    max_value = 0
    
    for n in numbers:
        if n > max_value:
            print(f"n={n} max_value={max_value}")
            max_value = n
   
    return max_value

# %%
themax = find_max([5,3,7])

print( f"Maximum: {themax}" )
