# %%
# Initialize Otter
import otter
grader = otter.Notebook("w06Alec.ipynb")

# %% [markdown]
# ---
#
# <h3><center>E7 -  Introduction to Programming for Scientists and Engineers</center></h3>
#
# <h2><center>Lecture w06-A <br></center></h2>
# <h2><center>Working with files</h2>
#
# ---

# %% [markdown]
# ### The [`pathlib`](https://docs.python.org/3/library/pathlib.html) package

# %%
from pathlib import Path

# %% [markdown]
# #### Iterate through directories

# %% [markdown]
# ### Writing arbitrary text

# %%
outfile = Path.cwd() / 'write_test.txt'
with open(outfile,'w') as f:
    f.write('First line\n')
    f.write('Second line\n')

# %% [markdown]
# ### Reading arbitrary text

# %%
infile = Path.cwd() / 'write_test.txt'
with open(infile,'r') as f:
    for line in f.readlines():
        print(line)

# %% [markdown]
# ### The [pickle](https://docs.python.org/3/library/pickle.html) package

# %%
import pickle

# %%
X = [{ 'type' : 'A',
       'size' : 29,
       'cost' : 1.50 },
     { 'type' : 'B',
       'size' : 19,
       'cost' : 1.30 } ]
Y = 'This is a string.'

# %%
outfile = Path.cwd()/'my_data.pickle'
with open(outfile,'wb') as f:
    pickle.dump((X,Y),f)

# %%
infile = Path.cwd()/'my_data.pickle'
with open(infile,'rb') as f:
    X, Y = pickle.load(f)

# %% [markdown]
# ### Writing NumPy arrays to text files

# %%
import numpy as np

# %%
A = np.array([[1,2,3],[4,5,6]])

# %% [markdown]
# ### Reading NumPy arrays from text files

# %% [markdown]
# ### Writing NumPy arrays to binary files

# %%
A = np.array([[1,2,3],[4,5,6]])
B = np.array([1,2,3])

# %% [markdown]
# #### One variable per file

# %% [markdown]
# #### Multiple variables per file

# %% [markdown]
# ### Reading NumPy arrays from binary files

# %% [markdown]
# #### One variable per file

# %% [markdown]
# #### Multiple variables per file

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**
#
# Make sure you submit the .zip file to Gradescope.

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export(pdf=False)
